# %%
#W4A1
try:
    n = int(input('Nhập số nguyên n:'))
    if n > 0:
        for i in range(1, n+1, 1):
            print(i, end= " ")

# %%
#W4A3
while True:
    n = int(input('Nhập số nguyên n (0<n<100):'))
    if 0 < n < 100: 
        break
    else:
        print('Hãy
